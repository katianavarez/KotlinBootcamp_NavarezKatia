// %%
val trout = "trout"
val haddock = "haddock"
val snapper = "snapper"
println("I dont like $trout, i dont like $haddock & i dont like $snapper")
// Out:
// I dont like trout, i dont like haddock & i dont like snapper

// %%
var fishName = "haddock"
when (fishName.length) {
    0 -> println("Error: Fish name is empty.")
    in 3..12 -> println("Good fish name")
    else -> println("OK fish name")
}
// Out:
// Good fish name
