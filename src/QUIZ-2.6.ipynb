// %%
2.plus(71).plus(233).minus(13).div(30).plus(1)
// Out:
// 10

// %%
var rainbowColor = "pink"
rainbowColor = "blue"

val blackColor = "black"
// blackColor = "white" | Error: val cannot be reassigned

// %%
// rainbowColor = null | Error: Null can not be a value of a non-null type String
var greenColor: String? = null
var blueColor = null

// %%
var list1 = listOf(null, null)
var list2 = mutableListOf<Int?>(null, null)
var list3: List<Int>? = null

// %%
var nullTest: Int? = null
println(nullTest?.inc() ?:0)
// Out:
// 0
