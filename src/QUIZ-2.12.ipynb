// %%
var numbers = arrayOf(11, 12, 13, 14, 15)
var strings =  mutableListOf<String>()
for (num in numbers) {
    strings.add(num.toString())
}
println(strings)
// Out:
// [11, 12, 13, 14, 15]

// %%
// Challenge
var divisible7 = mutableListOf<Int>()
for (num in 0..100) {
    if (num %7 == 0){
        divisible7.add(num)
    }
}
println(divisible7)
// Out:
// [0, 7, 14, 21, 28, 35, 42, 49, 56, 63, 70, 77, 84, 91, 98]

// %%
for (i in 0..100 step 7) println(i.toString() + " - ")
// Out:
// 0 -
// 7 -
// 14 -
// 21 -
// 28 -
// 35 -
// 42 -
// 49 -
// 56 -
// 63 -
// 70 -
// 77 -
// 84 -
// 91 -
// 98 -
